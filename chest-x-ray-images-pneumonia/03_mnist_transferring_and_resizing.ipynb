# %% [markdown]
# # Binary Classification with CNNs: Kaggle Data Set
# With transfer learning from the pneumonia MNIST data set

# %% [markdown]
# ## Setup

# %%
import numpy as np
import tensorflow as tf


import datetime

notebook_start_time = datetime.datetime.now()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782549424.768832  171942 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1782549425.676626  171942 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
test_dir = "data/test"
train_dir = "data/train"
validation_dir = "data/val"

height, width, channels = 150, 150, 1

batch_size = 32

# While working, I discovered that the tf.keras.preprocessing.image.ImageDataGenerator class is deprecated
# using this new API instead

train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=(height, width),
    batch_size=batch_size,
    label_mode="int",
    color_mode="grayscale",
)

validation_ds = tf.keras.utils.image_dataset_from_directory(
    validation_dir,
    image_size=(height, width),
    batch_size=batch_size,
    label_mode="int",
    color_mode="grayscale",
    shuffle=False,
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=(height, width),
    batch_size=batch_size,
    label_mode="int",
    color_mode="grayscale",
    shuffle=False,
)

# because the outputs are batched, we have to concatenate all the batches
y_true = np.concatenate([y for x, y in test_ds], axis=0)
# Out:
# Found 4442 files belonging to 2 classes.
# Found 790 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
from visualization import reset_keras, show_confusion_matrix, summary_graphics

# %%
def get_class_training_weights(assignments, normalize=True):
    # inverse-frequency weighting: up-weight the MINORITY class
    n_total = len(assignments)
    n_pos = float(sum(assignments))  # number of class-1 (pneumonia) labels
    n_neg = n_total - n_pos  # number of class-0 (normal) labels
    weight_0 = n_total / (2 * n_neg)
    weight_1 = n_total / (2 * n_pos)
    if normalize:
        denom = max(weight_0, weight_1)
        weight_0 = weight_0 / denom
        weight_1 = weight_1 / denom
    return {0: weight_0, 1: weight_1}


class_weight = get_class_training_weights(tf.concat([y for x, y in train_ds], axis=0))

print(f"Weight for normal class: {class_weight[0]:1.3f}")
print(f"Weight for pneumonia class: {class_weight[1]:1.3f}")
# Out:
# Weight for normal class: 1.000
# Weight for pneumonia class: 0.348

# %% [markdown]
# ## Training

# %%
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
transfer_model.summary()
# Out:
# Model: "Model_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ 0.1rflip (RandomFlip)           │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 0.2rrot (RandomRotation)        │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 0.3rtran (RandomTranslation)    │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescale (Rescaling)             │ (None, 28, 28, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 1.1conv (Conv2D)                │ (None, 28, 28, 16)     │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 1.2conv (Conv2D)                │ (None, 28, 28, 16)     │         2,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 1.3pool (MaxPooling2D)          │ (None, 14, 14, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2.1conv (Conv2D)                │ (None, 14, 14, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2.2conv (Conv2D)                │ (None, 14, 14, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 2.3pool (MaxPooling2D)          │ (None, 7, 7, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 3.1conv (SeparableConv2D)       │ (None, 7, 7, 64)       │         2,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 3.2batchnorm                    │ (None, 7, 7, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 3.3conv (SeparableConv2D)       │ (None, 7, 7, 64)       │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 3.4pool (MaxPooling2D)          │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 4.1conv (SeparableConv2D)       │ (None, 4, 4, 64)       │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 4.2batchnorm                    │ (None, 4, 4, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 4.3conv (SeparableConv2D)       │ (None, 4, 4, 64)       │         4,736 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 4.6pool (MaxPooling2D)          │ (None, 2, 2, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 5.1flatten (Flatten)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 5.2dense (Dense)                │ (None, 512)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 5.3dropout (Dropout)            │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 5.4dense (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ 5.5dropout (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 889,461 (3.39 MB)
#  Trainable params: 296,401 (1.13 MB)
#  Non-trainable params: 256 (1.00 KB)
#  Optimizer params: 592,804 (2.26 MB)

# %%
reset_keras()

model_1 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(
            28, 28, name="resizing"
        ),  # mnist data set is 28 x 28 x 1
        transfer_model,
    ],
    name="Model_1",
)

metrics = [
    tf.keras.metrics.TruePositives(name="tp"),
    tf.keras.metrics.TrueNegatives(name="tn"),
    tf.keras.metrics.BinaryAccuracy(name="accuracy"),
    tf.keras.metrics.Precision(name="precision"),
    tf.keras.metrics.Recall(name="recall"),
]

model_1.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

y_pred = np.round(model_1.predict(test_ds))

show_confusion_matrix(y_true, y_pred)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step

# %%
def make_callbacks(filepath):
    return [
        tf.keras.callbacks.ModelCheckpoint(
            filepath=filepath, save_best_only=True, monitor="val_loss", mode="min"
        ),
        tf.keras.callbacks.EarlyStopping(
            monitor="val_loss", mode="min", patience=5, restore_best_weights=True
        ),
        tf.keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", mode="min", factor=0.5, patience=3
        ),
    ]


epochs = 30

history = model_1.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_1.keras"),
)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 34ms/step - accuracy: 0.7812 - loss: 0.2296 - precision: 0.9294 - recall: 0.7630 - tn: 955.0000 - tp: 2515.0000 - val_accuracy: 0.2810 - val_loss: 1.8228 - val_precision: 1.0000 - val_recall: 0.0324 - val_tn: 203.0000 - val_tp: 19.0000 - learning_rate: 0.0010
# Epoch 2/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8064 - loss: 0.2157 - precision: 0.9316 - recall: 0.7976 - tn: 953.0000 - tp: 2629.0000 - val_accuracy: 0.7671 - val_loss: 0.4997 - val_precision: 0.9278 - val_recall: 0.7445 - val_tn: 169.0000 - val_tp: 437.0000 - learning_rate: 0.0010
# Epoch 3/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8267 - loss: 0.1940 - precision: 0.9407 - recall: 0.8180 - tn: 976.0000 - tp: 2696.0000 - val_accuracy: 0.6380 - val_loss: 0.7004 - val_precision: 0.9902 - val_recall: 0.5179 - val_tn: 200.0000 - val_tp: 304.0000 - learning_rate: 0.0010
# Epoch 4/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.8399 - loss: 0.1839 - precision: 0.9440 - recall: 0.8337 - tn: 983.0000 - tp: 2748.0000 - val_accuracy: 0.2873 - val_loss: 2.3377 - val_precision: 1.0000 - val_recall: 0.0409 - val_tn: 203.0000 - val_tp: 24.0000 - learning_rate: 0.0010
# Epoch 5/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.8449 - loss: 0.1796 - precision: 0.9478 - recall: 0.8371 - tn: 994.0000 - tp: 2759.0000 - val_accuracy: 0.5165 - val_loss: 0.9816 - val_precision: 0.9904 - val_recall: 0.3526 - val_tn: 201.0000 - val_tp: 207.0000 - learning_rate: 0.0010
# Epoch 6/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 10s 68ms/step - accuracy: 0.8658 - loss: 0.1572 - precision: 0.9576 - recall: 0.8571 - tn: 1021.0000 - tp: 2825.0000 - val_accuracy: 0.4165 - val_loss: 1.7322 - val_precision: 1.0000 - val_recall: 0.2147 - val_tn: 203.0000 - val_tp: 126.0000 - learning_rate: 5.0000e-04
# Epoch 7/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - accuracy: 0.8870 - loss: 0.1399 - precision: 0.9626 - recall: 0.8820 - tn: 1033.0000 - tp: 2907.0000 - val_accuracy: 0.6253 - val_loss: 0.8755 - val_precision: 0.9966 - val_recall: 0.4974 - val_tn: 202.0000 - val_tp: 292.0000 - learning_rate: 5.0000e-04

# %%
summary_graphics(history, model_1, test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step

# %%
reset_keras()

transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_2 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(512, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(256, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_2",
)

# copy over the weights
model_2.get_layer("1.1conv").set_weights(
    transfer_model.get_layer("1.1conv").get_weights()
)
model_2.get_layer("1.2conv").set_weights(
    transfer_model.get_layer("1.2conv").get_weights()
)
model_2.get_layer("2.1conv").set_weights(
    transfer_model.get_layer("2.1conv").get_weights()
)
model_2.get_layer("2.2conv").set_weights(
    transfer_model.get_layer("2.2conv").get_weights()
)
model_2.get_layer("3.1conv").set_weights(
    transfer_model.get_layer("3.1conv").get_weights()
)
model_2.get_layer("3.3conv").set_weights(
    transfer_model.get_layer("3.3conv").get_weights()
)
model_2.get_layer("4.1conv").set_weights(
    transfer_model.get_layer("4.1conv").get_weights()
)
model_2.get_layer("4.3conv").set_weights(
    transfer_model.get_layer("4.3conv").get_weights()
)
model_2.get_layer("5.2dense").set_weights(
    transfer_model.get_layer("5.2dense").get_weights()
)
model_2.get_layer("5.4dense").set_weights(
    transfer_model.get_layer("5.4dense").get_weights()
)
# model_2.get_layer("output").set_weights(transfer_model.get_layer("output"))

model_2.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_2.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_2.keras"),
)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 16s 85ms/step - accuracy: 0.7716 - loss: 0.2253 - precision: 0.9366 - recall: 0.7425 - tn: 1154.0000 - tp: 2883.0000 - val_accuracy: 0.2570 - val_loss: 0.8628 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - accuracy: 0.8046 - loss: 0.2049 - precision: 0.9408 - recall: 0.7861 - tn: 983.0000 - tp: 2591.0000 - val_accuracy: 0.2570 - val_loss: 0.8277 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.8359 - loss: 0.1857 - precision: 0.9452 - recall: 0.8268 - tn: 988.0000 - tp: 2725.0000 - val_accuracy: 0.2582 - val_loss: 0.8962 - val_precision: 1.0000 - val_recall: 0.0017 - val_tn: 203.0000 - val_tp: 1.0000 - learning_rate: 0.0010
# Epoch 4/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - accuracy: 0.8404 - loss: 0.1771 - precision: 0.9502 - recall: 0.8283 - tn: 1003.0000 - tp: 2730.0000 - val_accuracy: 0.3203 - val_loss: 1.1889 - val_precision: 1.0000 - val_recall: 0.0852 - val_tn: 203.0000 - val_tp: 50.0000 - learning_rate: 0.0010
# Epoch 5/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8516 - loss: 0.1692 - precision: 0.9526 - recall: 0.8419 - tn: 1008.0000 - tp: 2775.0000 - val_accuracy: 0.3266 - val_loss: 1.6167 - val_precision: 1.0000 - val_recall: 0.0937 - val_tn: 203.0000 - val_tp: 55.0000 - learning_rate: 0.0010
# Epoch 6/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.8690 - loss: 0.1508 - precision: 0.9622 - recall: 0.8571 - tn: 1035.0000 - tp: 2825.0000 - val_accuracy: 0.8063 - val_loss: 0.4196 - val_precision: 0.9865 - val_recall: 0.7496 - val_tn: 197.0000 - val_tp: 440.0000 - learning_rate: 5.0000e-04
# Epoch 7/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.8865 - loss: 0.1349 - precision: 0.9632 - recall: 0.8808 - tn: 1035.0000 - tp: 2903.0000 - val_accuracy: 0.7722 - val_loss: 0.5413 - val_precision: 0.9880 - val_recall: 0.7019 - val_tn: 198.0000 - val_tp: 412.0000 - learning_rate: 5.0000e-04
# Epoch 8/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - accuracy: 0.8865 - loss: 0.1386 - precision: 0.9641 - recall: 0.8799 - tn: 1038.0000 - tp: 2900.0000 - val_accuracy: 0.9241 - val_loss: 0.2133 - val_precision: 0.9782 - val_recall: 0.9182 - val_tn: 191.0000 - val_tp: 539.0000 - learning_rate: 5.0000e-04
# Epoch 9/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - accuracy: 0.8854 - loss: 0.1337 - precision: 0.9631 - recall: 0.8792 - tn: 1035.0000 - tp: 2898.0000 - val_accuracy: 0.8291 - val_loss: 0.3818 - val_precision: 0.9934 - val_recall: 0.7751 - val_tn: 200.0000 - val_tp: 455.0000 - learning_rate: 5.0000e-04
# Epoch 10/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9005 - loss: 0.1228 - precision: 0.9738 - recall: 0.8899 - tn: 1067.0000 - tp: 2933.0000 - val_accuracy: 0.7570 - val_loss: 0.5163 - val_precision: 0.9975 - val_recall: 0.6746 - val_tn: 202.0000 - val_tp: 396.0000 - learning_rate: 5.0000e-04
# Epoch 11/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8949 - loss: 0.1270 - precision: 0.9701 - recall: 0.8856 - tn: 1056.0000 - tp: 2919.0000 - val_accuracy: 0.9038 - val_loss: 0.2369 - val_precision: 0.9830 - val_recall: 0.8859 - val_tn: 194.0000 - val_tp: 520.0000 - learning_rate: 5.0000e-04
# Epoch 12/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8940 - loss: 0.1217 - precision: 0.9688 - recall: 0.8856 - tn: 1052.0000 - tp: 2919.0000 - val_accuracy: 0.4430 - val_loss: 1.5725 - val_precision: 1.0000 - val_recall: 0.2504 - val_tn: 203.0000 - val_tp: 147.0000 - learning_rate: 2.5000e-04
# Epoch 13/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.9118 - loss: 0.1128 - precision: 0.9758 - recall: 0.9035 - tn: 1072.0000 - tp: 2978.0000 - val_accuracy: 0.8253 - val_loss: 0.3866 - val_precision: 0.9912 - val_recall: 0.7717 - val_tn: 199.0000 - val_tp: 453.0000 - learning_rate: 2.5000e-04

# %%
best_model = tf.keras.models.load_model("best_model_restransfer_2.keras")
summary_graphics(history, best_model, test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
reset_keras()

# continue doing transfer learning but increase dropout in the dense layers
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_3 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(512, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.7, name="5.3dropout"),
        tf.keras.layers.Dense(256, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.5, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_3",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
    "3.1conv",
    "3.3conv",
    "4.1conv",
    "4.3conv",
    "5.2dense",
    "5.4dense",
]

for layer_name in layer_names:
    model_3.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )

model_3.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_3.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_3.keras"),
)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 9s 46ms/step - accuracy: 0.7735 - loss: 0.2381 - precision: 0.9307 - recall: 0.7507 - tn: 1132.0000 - tp: 2915.0000 - val_accuracy: 0.2570 - val_loss: 0.8425 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8109 - loss: 0.2093 - precision: 0.9352 - recall: 0.8007 - tn: 963.0000 - tp: 2639.0000 - val_accuracy: 0.2570 - val_loss: 0.8142 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.8330 - loss: 0.1833 - precision: 0.9484 - recall: 0.8195 - tn: 999.0000 - tp: 2701.0000 - val_accuracy: 0.2570 - val_loss: 0.8059 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 4/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8386 - loss: 0.1823 - precision: 0.9470 - recall: 0.8289 - tn: 993.0000 - tp: 2732.0000 - val_accuracy: 0.2608 - val_loss: 1.0828 - val_precision: 1.0000 - val_recall: 0.0051 - val_tn: 203.0000 - val_tp: 3.0000 - learning_rate: 0.0010
# Epoch 5/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8494 - loss: 0.1684 - precision: 0.9572 - recall: 0.8343 - tn: 1023.0000 - tp: 2750.0000 - val_accuracy: 0.8835 - val_loss: 0.2838 - val_precision: 0.9732 - val_recall: 0.8671 - val_tn: 189.0000 - val_tp: 509.0000 - learning_rate: 0.0010
# Epoch 6/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8505 - loss: 0.1748 - precision: 0.9573 - recall: 0.8359 - tn: 1023.0000 - tp: 2755.0000 - val_accuracy: 0.8063 - val_loss: 0.3678 - val_precision: 0.8173 - val_recall: 0.9523 - val_tn: 78.0000 - val_tp: 559.0000 - learning_rate: 0.0010
# Epoch 7/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8757 - loss: 0.1515 - precision: 0.9635 - recall: 0.8653 - tn: 1038.0000 - tp: 2852.0000 - val_accuracy: 0.4114 - val_loss: 1.2076 - val_precision: 1.0000 - val_recall: 0.2078 - val_tn: 203.0000 - val_tp: 122.0000 - learning_rate: 0.0010
# Epoch 8/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8778 - loss: 0.1439 - precision: 0.9621 - recall: 0.8695 - tn: 1033.0000 - tp: 2866.0000 - val_accuracy: 0.5949 - val_loss: 0.8723 - val_precision: 0.9963 - val_recall: 0.4566 - val_tn: 202.0000 - val_tp: 268.0000 - learning_rate: 0.0010
# Epoch 9/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8926 - loss: 0.1287 - precision: 0.9694 - recall: 0.8832 - tn: 1054.0000 - tp: 2911.0000 - val_accuracy: 0.9000 - val_loss: 0.2418 - val_precision: 0.9885 - val_recall: 0.8756 - val_tn: 197.0000 - val_tp: 514.0000 - learning_rate: 5.0000e-04
# Epoch 10/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8949 - loss: 0.1189 - precision: 0.9739 - recall: 0.8820 - tn: 1068.0000 - tp: 2907.0000 - val_accuracy: 0.9025 - val_loss: 0.2391 - val_precision: 0.9811 - val_recall: 0.8859 - val_tn: 193.0000 - val_tp: 520.0000 - learning_rate: 5.0000e-04
# Epoch 11/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - accuracy: 0.8991 - loss: 0.1215 - precision: 0.9718 - recall: 0.8899 - tn: 1061.0000 - tp: 2933.0000 - val_accuracy: 0.7924 - val_loss: 0.4884 - val_precision: 0.9907 - val_recall: 0.7274 - val_tn: 199.0000 - val_tp: 427.0000 - learning_rate: 5.0000e-04
# Epoch 12/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9133 - loss: 0.1088 - precision: 0.9764 - recall: 0.9050 - tn: 1074.0000 - tp: 2983.0000 - val_accuracy: 0.8810 - val_loss: 0.3167 - val_precision: 0.8652 - val_recall: 0.9949 - val_tn: 112.0000 - val_tp: 584.0000 - learning_rate: 5.0000e-04
# Epoch 13/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - accuracy: 0.9127 - loss: 0.1112 - precision: 0.9721 - recall: 0.9084 - tn: 1060.0000 - tp: 2994.0000 - val_accuracy: 0.5646 - val_loss: 0.9856 - val_precision: 1.0000 - val_recall: 0.4140 - val_tn: 203.0000 - val_tp: 243.0000 - learning_rate: 5.0000e-04
# Epoch 14/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9201 - loss: 0.1049 - precision: 0.9754 - recall: 0.9154 - tn: 1070.0000 - tp: 3017.0000 - val_accuracy: 0.9089 - val_loss: 0.2451 - val_precision: 0.9924 - val_recall: 0.8842 - val_tn: 199.0000 - val_tp: 519.0000 - learning_rate: 2.5000e-04
# Epoch 15/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - accuracy: 0.9145 - loss: 0.1019 - precision: 0.9725 - recall: 0.9105 - tn: 1061.0000 - tp: 3001.0000 - val_accuracy: 0.9316 - val_loss: 0.1854 - val_precision: 0.9890 - val_recall: 0.9182 - val_tn: 197.0000 - val_tp: 539.0000 - learning_rate: 2.5000e-04
# Epoch 16/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.9205 - loss: 0.1016 - precision: 0.9733 - recall: 0.9181 - tn: 1063.0000 - tp: 3026.0000 - val_accuracy: 0.7646 - val_loss: 0.6155 - val_precision: 0.9975 - val_recall: 0.6848 - val_tn: 202.0000 - val_tp: 402.0000 - learning_rate: 2.5000e-04
# Epoch 17/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - accuracy: 0.9210 - loss: 0.1021 - precision: 0.9733 - recall: 0.9187 - tn: 1063.0000 - tp: 3028.0000 - val_accuracy: 0.9127 - val_loss: 0.2335 - val_precision: 0.9887 - val_recall: 0.8927 - val_tn: 197.0000 - val_tp: 524.0000 - learning_rate: 2.5000e-04
# Epoch 18/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 12s 88ms/step - accuracy: 0.9219 - loss: 0.1025 - precision: 0.9712 - recall: 0.9220 - tn: 1056.0000 - tp: 3039.0000 - val_accuracy: 0.9291 - val_loss: 0.1651 - val_precision: 0.9262 - val_recall: 0.9830 - val_tn: 157.0000 - val_tp: 577.0000 - learning_rate: 2.5000e-04
# Epoch 19/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - accuracy: 0.9316 - loss: 0.0904 - precision: 0.9789 - recall: 0.9278 - tn: 1080.0000 - tp: 3058.0000 - val_accuracy: 0.9481 - val_loss: 0.1463 - val_precision: 0.9707 - val_recall: 0.9591 - val_tn: 186.0000 - val_tp: 563.0000 - learning_rate: 2.5000e-04
# Epoch 20/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - accuracy: 0.9239 - loss: 0.0931 - precision: 0.9762 - recall: 0.9199 - tn: 1072.0000 - tp: 3032.0000 - val_accuracy: 0.8759 - val_loss: 0.2872 - val_precision: 0.9920 - val_recall: 0.8399 - val_tn: 199.0000 - val_tp: 493.0000 - learning_rate: 2.5000e-04
# Epoch 21/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.9250 - loss: 0.0937 - precision: 0.9771 - recall: 0.9205 - tn: 1075.0000 - tp: 3034.0000 - val_accuracy: 0.9481 - val_loss: 0.1503 - val_precision: 0.9823 - val_recall: 0.9472 - val_tn: 193.0000 - val_tp: 556.0000 - learning_rate: 2.5000e-04
# Epoch 22/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - accuracy: 0.9273 - loss: 0.0897 - precision: 0.9775 - recall: 0.9232 - tn: 1076.0000 - tp: 3043.0000 - val_accuracy: 0.9304 - val_loss: 0.1626 - val_precision: 0.9290 - val_recall: 0.9813 - val_tn: 159.0000 - val_tp: 576.0000 - learning_rate: 2.5000e-04
# Epoch 23/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.9250 - loss: 0.0899 - precision: 0.9815 - recall: 0.9163 - tn: 1089.0000 - tp: 3020.0000 - val_accuracy: 0.9380 - val_loss: 0.1665 - val_precision: 0.9770 - val_recall: 0.9387 - val_tn: 190.0000 - val_tp: 551.0000 - learning_rate: 1.2500e-04
# Epoch 24/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 80ms/step - accuracy: 0.9307 - loss: 0.0844 - precision: 0.9782 - recall: 0.9272 - tn: 1078.0000 - tp: 3056.0000 - val_accuracy: 0.9190 - val_loss: 0.1747 - val_precision: 0.9157 - val_recall: 0.9813 - val_tn: 150.0000 - val_tp: 576.0000 - learning_rate: 1.2500e-04

# %%
best_model = tf.keras.models.load_model("best_model_restransfer_3.keras")
summary_graphics(history, best_model, test_ds)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step

# %%
reset_keras()

# add in a small amount of dropout everywhere
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_4 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.Dropout(0.2),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(512, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(256, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_4",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
    "3.1conv",
    "3.3conv",
    "4.1conv",
    "4.3conv",
    "5.2dense",
    "5.4dense",
]

for layer_name in layer_names:
    model_4.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )

model_4.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_4.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_4.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_4.keras")
summary_graphics(history, best_model, test_ds)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 11s 55ms/step - accuracy: 0.6460 - loss: 0.3197 - precision: 0.8577 - recall: 0.6271 - tn: 945.0000 - tp: 2435.0000 - val_accuracy: 0.2570 - val_loss: 0.7440 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.7904 - loss: 0.2242 - precision: 0.9359 - recall: 0.7703 - tn: 972.0000 - tp: 2539.0000 - val_accuracy: 0.2570 - val_loss: 0.7282 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - val_tn: 203.0000 - val_tp: 0.0000e+00 - learning_rate: 0.0010
# Epoch 3/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 53ms/step - accuracy: 0.7976 - loss: 0.2196 - precision: 0.9376 - recall: 0.7791 - tn: 975.0000 - tp: 2568.0000 - val_accuracy: 0.2810 - val_loss: 0.7384 - val_precision: 1.0000 - val_recall: 0.0324 - val_tn: 203.0000 - val_tp: 19.0000 - learning_rate: 0.0010
# Epoch 4/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8066 - loss: 0.1987 - precision: 0.9369 - recall: 0.7928 - tn: 970.0000 - tp: 2613.0000 - val_accuracy: 0.5861 - val_loss: 0.6092 - val_precision: 0.9962 - val_recall: 0.4446 - val_tn: 202.0000 - val_tp: 261.0000 - learning_rate: 0.0010
# Epoch 5/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8393 - loss: 0.1878 - precision: 0.9498 - recall: 0.8271 - tn: 1002.0000 - tp: 2726.0000 - val_accuracy: 0.6848 - val_loss: 0.6024 - val_precision: 0.9856 - val_recall: 0.5843 - val_tn: 198.0000 - val_tp: 343.0000 - learning_rate: 0.0010
# Epoch 6/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8370 - loss: 0.1937 - precision: 0.9444 - recall: 0.8292 - tn: 985.0000 - tp: 2733.0000 - val_accuracy: 0.8810 - val_loss: 0.3091 - val_precision: 0.9607 - val_recall: 0.8756 - val_tn: 182.0000 - val_tp: 514.0000 - learning_rate: 0.0010
# Epoch 7/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8399 - loss: 0.1785 - precision: 0.9468 - recall: 0.8310 - tn: 992.0000 - tp: 2739.0000 - val_accuracy: 0.9101 - val_loss: 0.2309 - val_precision: 0.9526 - val_recall: 0.9250 - val_tn: 176.0000 - val_tp: 543.0000 - learning_rate: 0.0010
# Epoch 8/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8528 - loss: 0.1717 - precision: 0.9533 - recall: 0.8428 - tn: 1010.0000 - tp: 2778.0000 - val_accuracy: 0.8025 - val_loss: 0.3842 - val_precision: 0.9843 - val_recall: 0.7462 - val_tn: 196.0000 - val_tp: 438.0000 - learning_rate: 0.0010
# Epoch 9/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8503 - loss: 0.1724 - precision: 0.9544 - recall: 0.8383 - tn: 1014.0000 - tp: 2763.0000 - val_accuracy: 0.6456 - val_loss: 0.6823 - val_precision: 0.9968 - val_recall: 0.5247 - val_tn: 202.0000 - val_tp: 308.0000 - learning_rate: 0.0010
# Epoch 10/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8541 - loss: 0.1733 - precision: 0.9506 - recall: 0.8474 - tn: 1001.0000 - tp: 2793.0000 - val_accuracy: 0.9051 - val_loss: 0.2524 - val_precision: 0.9588 - val_recall: 0.9114 - val_tn: 180.0000 - val_tp: 535.0000 - learning_rate: 0.0010
# Epoch 11/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8706 - loss: 0.1523 - precision: 0.9561 - recall: 0.8653 - tn: 1015.0000 - tp: 2852.0000 - val_accuracy: 0.9051 - val_loss: 0.2394 - val_precision: 0.9354 - val_recall: 0.9370 - val_tn: 165.0000 - val_tp: 550.0000 - learning_rate: 5.0000e-04
# Epoch 12/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - accuracy: 0.8753 - loss: 0.1408 - precision: 0.9604 - recall: 0.8677 - tn: 1028.0000 - tp: 2860.0000 - val_accuracy: 0.9278 - val_loss: 0.2012 - val_precision: 0.9617 - val_recall: 0.9404 - val_tn: 181.0000 - val_tp: 552.0000 - learning_rate: 5.0000e-04
# Epoch 13/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8820 - loss: 0.1387 - precision: 0.9679 - recall: 0.8698 - tn: 1051.0000 - tp: 2867.0000 - val_accuracy: 0.8924 - val_loss: 0.2540 - val_precision: 0.9808 - val_recall: 0.8722 - val_tn: 193.0000 - val_tp: 512.0000 - learning_rate: 5.0000e-04
# Epoch 14/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8859 - loss: 0.1381 - precision: 0.9638 - recall: 0.8792 - tn: 1037.0000 - tp: 2898.0000 - val_accuracy: 0.9114 - val_loss: 0.2120 - val_precision: 0.9691 - val_recall: 0.9097 - val_tn: 186.0000 - val_tp: 534.0000 - learning_rate: 5.0000e-04
# Epoch 15/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8901 - loss: 0.1336 - precision: 0.9686 - recall: 0.8805 - tn: 1052.0000 - tp: 2902.0000 - val_accuracy: 0.7785 - val_loss: 0.4599 - val_precision: 0.9905 - val_recall: 0.7087 - val_tn: 199.0000 - val_tp: 416.0000 - learning_rate: 5.0000e-04
# Epoch 16/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8874 - loss: 0.1311 - precision: 0.9651 - recall: 0.8802 - tn: 1041.0000 - tp: 2901.0000 - val_accuracy: 0.9304 - val_loss: 0.2065 - val_precision: 0.9650 - val_recall: 0.9404 - val_tn: 183.0000 - val_tp: 552.0000 - learning_rate: 2.5000e-04
# Epoch 17/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.8953 - loss: 0.1290 - precision: 0.9701 - recall: 0.8862 - tn: 1056.0000 - tp: 2921.0000 - val_accuracy: 0.9190 - val_loss: 0.1991 - val_precision: 0.9645 - val_recall: 0.9250 - val_tn: 183.0000 - val_tp: 543.0000 - learning_rate: 2.5000e-04
# Epoch 18/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 55ms/step - accuracy: 0.8964 - loss: 0.1232 - precision: 0.9668 - recall: 0.8911 - tn: 1045.0000 - tp: 2937.0000 - val_accuracy: 0.9354 - val_loss: 0.1739 - val_precision: 0.9637 - val_recall: 0.9489 - val_tn: 182.0000 - val_tp: 557.0000 - learning_rate: 2.5000e-04
# Epoch 19/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 54ms/step - accuracy: 0.9018 - loss: 0.1199 - precision: 0.9729 - recall: 0.8926 - tn: 1064.0000 - tp: 2942.0000 - val_accuracy: 0.9038 - val_loss: 0.2286 - val_precision: 0.9705 - val_recall: 0.8978 - val_tn: 187.0000 - val_tp: 527.0000 - learning_rate: 2.5000e-04
# Epoch 20/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.8955 - loss: 0.1258 - precision: 0.9667 - recall: 0.8899 - tn: 1045.0000 - tp: 2933.0000 - val_accuracy: 0.9367 - val_loss: 0.1822 - val_precision: 0.9543 - val_recall: 0.9608 - val_tn: 176.0000 - val_tp: 564.0000 - learning_rate: 2.5000e-04
# Epoch 21/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - accuracy: 0.9045 - loss: 0.1211 - precision: 0.9705 - recall: 0.8987 - tn: 1056.0000 - tp: 2962.0000 - val_accuracy: 0.9114 - val_loss: 0.2062 - val_precision: 0.9743 - val_recall: 0.9046 - val_tn: 189.0000 - val_tp: 531.0000 - learning_rate: 2.5000e-04
# Epoch 22/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9041 - loss: 0.1205 - precision: 0.9711 - recall: 0.8975 - tn: 1058.0000 - tp: 2958.0000 - val_accuracy: 0.9304 - val_loss: 0.1989 - val_precision: 0.9801 - val_recall: 0.9250 - val_tn: 192.0000 - val_tp: 543.0000 - learning_rate: 1.2500e-04
# Epoch 23/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - accuracy: 0.9007 - loss: 0.1181 - precision: 0.9707 - recall: 0.8932 - tn: 1057.0000 - tp: 2944.0000 - val_accuracy: 0.9089 - val_loss: 0.2152 - val_precision: 0.9795 - val_recall: 0.8961 - val_tn: 192.0000 - val_tp: 526.0000 - learning_rate: 1.2500e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
reset_keras()

# go back to original model, copy only early layers, and freeze them
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_5 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(512, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(256, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_5",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_5.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    model_5.get_layer(layer_name).trainable = False

model_5.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_5.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_5.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_5.keras")
summary_graphics(history, best_model, test_ds)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 9s 50ms/step - accuracy: 0.7315 - loss: 0.2577 - precision: 0.9278 - recall: 0.6920 - tn: 1140.0000 - tp: 2687.0000 - val_accuracy: 0.7430 - val_loss: 0.6474 - val_precision: 0.7430 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 587.0000 - learning_rate: 0.0010
# Epoch 2/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.7976 - loss: 0.2033 - precision: 0.9431 - recall: 0.7740 - tn: 992.0000 - tp: 2551.0000 - val_accuracy: 0.7430 - val_loss: 0.6618 - val_precision: 0.7430 - val_recall: 1.0000 - val_tn: 0.0000e+00 - val_tp: 587.0000 - learning_rate: 0.0010
# Epoch 3/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8201 - loss: 0.1977 - precision: 0.9410 - recall: 0.8083 - tn: 979.0000 - tp: 2664.0000 - val_accuracy: 0.4797 - val_loss: 0.6948 - val_precision: 1.0000 - val_recall: 0.2998 - val_tn: 203.0000 - val_tp: 176.0000 - learning_rate: 0.0010
# Epoch 4/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8422 - loss: 0.1754 - precision: 0.9513 - recall: 0.8298 - tn: 1006.0000 - tp: 2735.0000 - val_accuracy: 0.5051 - val_loss: 0.7188 - val_precision: 1.0000 - val_recall: 0.3339 - val_tn: 203.0000 - val_tp: 196.0000 - learning_rate: 0.0010
# Epoch 5/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8485 - loss: 0.1689 - precision: 0.9578 - recall: 0.8325 - tn: 1025.0000 - tp: 2744.0000 - val_accuracy: 0.3949 - val_loss: 1.1657 - val_precision: 1.0000 - val_recall: 0.1857 - val_tn: 203.0000 - val_tp: 109.0000 - learning_rate: 5.0000e-04
# Epoch 6/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8597 - loss: 0.1579 - precision: 0.9594 - recall: 0.8468 - tn: 1028.0000 - tp: 2791.0000 - val_accuracy: 0.7646 - val_loss: 0.4712 - val_precision: 0.9975 - val_recall: 0.6848 - val_tn: 202.0000 - val_tp: 402.0000 - learning_rate: 5.0000e-04
# Epoch 7/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - accuracy: 0.8602 - loss: 0.1531 - precision: 0.9620 - recall: 0.8450 - tn: 1036.0000 - tp: 2785.0000 - val_accuracy: 0.8494 - val_loss: 0.3313 - val_precision: 0.9815 - val_recall: 0.8126 - val_tn: 194.0000 - val_tp: 477.0000 - learning_rate: 5.0000e-04
# Epoch 8/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8647 - loss: 0.1502 - precision: 0.9610 - recall: 0.8522 - tn: 1032.0000 - tp: 2809.0000 - val_accuracy: 0.6772 - val_loss: 0.7412 - val_precision: 0.9970 - val_recall: 0.5673 - val_tn: 202.0000 - val_tp: 333.0000 - learning_rate: 5.0000e-04
# Epoch 9/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8778 - loss: 0.1420 - precision: 0.9652 - recall: 0.8665 - tn: 1043.0000 - tp: 2856.0000 - val_accuracy: 0.7646 - val_loss: 0.4753 - val_precision: 0.9951 - val_recall: 0.6865 - val_tn: 201.0000 - val_tp: 403.0000 - learning_rate: 5.0000e-04
# Epoch 10/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - accuracy: 0.8724 - loss: 0.1409 - precision: 0.9655 - recall: 0.8586 - tn: 1045.0000 - tp: 2830.0000 - val_accuracy: 0.7962 - val_loss: 0.3956 - val_precision: 0.9885 - val_recall: 0.7342 - val_tn: 198.0000 - val_tp: 431.0000 - learning_rate: 5.0000e-04
# Epoch 11/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - accuracy: 0.8814 - loss: 0.1390 - precision: 0.9673 - recall: 0.8695 - tn: 1049.0000 - tp: 2866.0000 - val_accuracy: 0.7747 - val_loss: 0.4732 - val_precision: 0.9952 - val_recall: 0.7002 - val_tn: 201.0000 - val_tp: 411.0000 - learning_rate: 2.5000e-04
# Epoch 12/30
# 139/139 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.8868 - loss: 0.1343 - precision: 0.9650 - recall: 0.8792 - tn: 1041.0000 - tp: 2898.0000 - val_accuracy: 0.7962 - val_loss: 0.4600 - val_precision: 0.9977 - val_recall: 0.7274 - val_tn: 202.0000 - val_tp: 427.0000 - learning_rate: 2.5000e-04
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step

# %%
reset_keras()

# do something similar to model 5 but increase number of neurons in later layers
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_6 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_6",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_6.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    model_6.get_layer(layer_name).trainable = False

model_6.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_6.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_6.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_6.keras")
summary_graphics(history, best_model, test_ds)
# Out:
# Epoch 1/30
# /home/sam/Documents/projects/ConvolutedComputerVision/.venv/lib/python3.12/site-packages/keras/src/trainers/epoch_iterator.py:74: UserWarning: `shuffle=True` was passed, but will be ignored since the data `x` was provided as a tf.data.Dataset. The Dataset is expected to already be shuffled (via `.shuffle(buffer_size)`).
#   self.data_adapter = data_adapters.get_data_adapter(
#  38/139 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.6899 - loss: 0.3003 - precision: 0.9464 - recall: 0.6121 - tn: 483.0000 - tp: 901.0000

# %%
reset_keras()

# let's try without dropout
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_7 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        # tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        # tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_7",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_7.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    model_7.get_layer(layer_name).trainable = False

model_7.compile(
    optimizer=tf.keras.optimizers.AdamW(),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_7.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_7.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_7.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# let's try without preprocessing and with lower learning rate
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_8 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # #tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        # tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        # tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        # tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        # tf.keras.layers.Dropout(0.4, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_8",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_8.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    model_8.get_layer(layer_name).trainable = False

model_8.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4
    ),  # 1e-4 instead of default 1e-3
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_8.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_8.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_8.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# add the preprocessing and dropout back in and try with even lower learning rate
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_9 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.5, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_9",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_9.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    model_9.get_layer(layer_name).trainable = False

model_9.compile(
    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-5
    ),  # 1e-5 instead of default 1e-3
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_9.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_9.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_9.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# try with learning rate not as low, and unfreeze the transferred layers
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_10 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        # tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.5, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_10",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_10.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    # model_9.get_layer(layer_name).trainable = False

model_10.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_10.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_10.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_10.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# try with lower dropout
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_11 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.3, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.3, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_11",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_11.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    # model_9.get_layer(layer_name).trainable = False

model_11.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=1e-4),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_11.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_11.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_11.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# try with a learning rate between 1e-4 and 1e-5
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_12 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.3, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.3, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_12",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_12.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    # model_9.get_layer(layer_name).trainable = False

model_12.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=(1e-4) / 2),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_12.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_12.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_12.keras")
summary_graphics(history, best_model, test_ds)

# %%
reset_keras()

# try with 0.5 dropout everywhere
transfer_model = tf.keras.models.load_model("best_model_mnist.keras")
model_13 = tf.keras.models.Sequential(
    [
        tf.keras.layers.InputLayer((150, 150, 1), name="input"),
        tf.keras.layers.Resizing(28, 28, name="rescaling"),
        # tf.keras.layers.RandomFlip("horizontal", name="0.1rflip"),
        tf.keras.layers.RandomRotation(0.2, name="0.2rrot"),
        tf.keras.layers.RandomTranslation(0.2, 0.2, name="0.3rtran"),
        tf.keras.layers.RandomZoom(0.2, name="0.4rzoom"),
        tf.keras.layers.Rescaling(1.0 / 255, name="rescale"),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.1conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Conv2D(
            16, (3, 3), activation="relu", padding="same", name="1.2conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="1.3pool"),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.1conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Conv2D(
            32, (3, 3), activation="relu", padding="same", name="2.2conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="2.3pool"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.1conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.BatchNormalization(name="3.2batchnorm"),
        tf.keras.layers.SeparableConv2D(
            64, (3, 3), activation="relu", padding="same", name="3.3conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="3.4pool"),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.1conv"
        ),
        tf.keras.layers.BatchNormalization(name="4.2batchnorm"),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.SeparableConv2D(
            128, (3, 3), activation="relu", padding="same", name="4.3conv"
        ),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.MaxPooling2D((2, 2), padding="same", name="4.6pool"),
        tf.keras.layers.Flatten(name="5.1flatten"),
        tf.keras.layers.Dense(1024, activation="relu", name="5.2dense"),
        tf.keras.layers.Dropout(0.5, name="5.3dropout"),
        tf.keras.layers.Dense(512, activation="relu", name="5.4dense"),
        tf.keras.layers.Dropout(0.5, name="5.5dropout"),
        tf.keras.layers.Dense(1, activation="sigmoid", name="output"),
    ],
    name="Model_13",
)

# copy over the weights
layer_names = [
    "1.1conv",
    "1.2conv",
    "2.1conv",
    "2.2conv",
]  # "3.1conv", "3.3conv", "4.1conv", "4.3conv", "5.2dense", "5.4dense"]

for layer_name in layer_names:
    model_13.get_layer(layer_name).set_weights(
        transfer_model.get_layer(layer_name).get_weights()
    )
    # model_9.get_layer(layer_name).trainable = False

model_13.compile(
    optimizer=tf.keras.optimizers.AdamW(learning_rate=(1e-4) / 2),
    loss=tf.keras.losses.BinaryCrossentropy(),
    metrics=metrics,
)

# %%
history = model_13.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs,
    class_weight=class_weight,
    verbose=1,
    callbacks=make_callbacks("best_model_restransfer_13.keras"),
)
best_model = tf.keras.models.load_model("best_model_restransfer_13.keras")
summary_graphics(history, best_model, test_ds)

# %%
notebook_end_time = datetime.datetime.now()
print(
    f"Notebook last run (end-to-end): {notebook_end_time} (duration: {notebook_end_time - notebook_start_time})"
)
